// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания № 4

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
//
// Описание задачи:
// Создать базовый класс Product в C#, который будет представлять информацию о
// продуктах.  На  основе  этого  класса  разработать  2-3  производных  класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
// Требования к базовому классу Product:
//
// • Атрибуты: Название (Name), Цена (Price), Производитель (Manufacturer).
//
// • Методы:
//
//     o GetInfo(): метод для получения информации о продукте в виде строки.
//
//     o Discount(): метод для применения скидки к цене продукта.
//
//     o Display(): метод для отображения информации о продукте на экране.
//
// Требования к производным классам:
// 1. Электроника  (Electronics):  Должен  содержать  дополнительные  атрибуты,
// такие как Гарантийный срок (WarrantyPeriod). Метод Discount() должен быть
// переопределен  для  добавления  логики  учета  гарантийного  срока  при
// применении скидки.
// 2. Одежда (Clothing): Должен содержать дополнительные атрибуты, такие как
// Размер (Size). Метод Display() должен быть переопределен для добавления
// информации о размере при отображении информации о продукте.
// 3. Книги  (Books) (если  требуется  третий  класс):  Должен  содержать
// дополнительные атрибуты, такие как Автор (Author). Метод GetInfo() должен
// быть  переопределен  для  включения  информации  об  авторе  в  описании
// продукта
//
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) и реализуйте простое, сложное и множественное наследование

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System.Collections.Generic;

// Интерфейсы
public interface IDiscountable { void ApplyDiscount(decimal percentage); }
public interface IShippable { decimal CalculateShipping(); }

// Базовый класс
public abstract class Product : IDiscountable
{
    public string Name { get; set; }
    public decimal Price { get; set; }
    public string Manufacturer { get; set; }
    public int StockQuantity { get; set; }

    public Product(string name, decimal price, string manufacturer, int stock)
    {
        Name = name;
        Price = price;
        Manufacturer = manufacturer;
        StockQuantity = stock;
    }

    public virtual string GetInfo() => $"Название: {Name}\nЦена: {Price:C}\nПроизводитель: {Manufacturer}";
    public virtual void ApplyDiscount(decimal percentage) => Price -= Price * (percentage / 100);
    public abstract string GetCategory();
}

// Простое наследование
public class Electronics : Product, IShippable
{
    public int WarrantyPeriod { get; set; }
    
    public Electronics(string name, decimal price, string manufacturer, int stock, int warranty) 
        : base(name, price, manufacturer, stock) => WarrantyPeriod = warranty;

    public override string GetInfo() => base.GetInfo() + $"\nГарантия: {WarrantyPeriod} мес.";
    public decimal CalculateShipping() => 300;
    public override string GetCategory() => "Электроника";
}

public class Clothing : Product, IShippable
{
    public string Size { get; set; }
    
    public Clothing(string name, decimal price, string manufacturer, int stock, string size) 
        : base(name, price, manufacturer, stock) => Size = size;

    public override string GetInfo() => base.GetInfo() + $"\nРазмер: {Size}";
    public decimal CalculateShipping() => 150;
    public override string GetCategory() => "Одежда";
}

// Сложное наследование
public class Smartphone : Electronics
{
    public string OS { get; set; }
    
    public Smartphone(string name, decimal price, string manufacturer, int stock, int warranty, string os) 
        : base(name, price, manufacturer, stock, warranty) => OS = os;

    public override string GetInfo() => base.GetInfo() + $"\nОС: {OS}";
}

// Корзина
public class ShoppingCart
{
    private List<Product> items = new List<Product>();

    public void AddProduct(Product product) => items.Add(product);
    
    public void ShowCart()
    {
        Console.WriteLine("🛒 Корзина:");
        foreach (var item in items) Console.WriteLine(item.GetInfo() + "\n---");
    }
    
    public decimal GetTotal()
    {
        decimal total = 0;
        foreach (var item in items) total += item.Price;
        return total;
    }
}

// Демо
public class ProgramDemo
{
    public static void RunDemo()
    {
        Console.WriteLine("СИСТЕМА МАГАЗИНА \n");

        // Создание товаров
        Smartphone phone = new Smartphone("iPhone 15", 89990, "Apple", 10, 24, "iOS");
        Clothing jacket = new Clothing("Куртка", 7500, "Nike", 20, "L");
        
        // Корзина
        ShoppingCart cart = new ShoppingCart();
        cart.AddProduct(phone);
        cart.AddProduct(jacket);
        
        // Показ корзины
        cart.ShowCart();
        Console.WriteLine($"$ Итого: {cart.GetTotal():C}");

        // Демонстрация полиморфизма
        Console.WriteLine("\n ПОЛИМОРФИЗМ:");
        Product[] products = { phone, jacket };
        foreach (var product in products)
        {
            Console.WriteLine($"{product.GetCategory()}: {product.Name}");
            product.ApplyDiscount(10);
            Console.WriteLine($"Цена со скидкой: {product.Price:C}");
        }
    }
}

ProgramDemo.RunDemo();
// Out:
// 🚀 УПРОЩЕННАЯ СИСТЕМА МАГАЗИНА
//
// 🛒 Корзина:
// Название: iPhone 15
// Цена: ¤89,990.00
// Производитель: Apple
// Гарантия: 24 мес.
// ОС: iOS
// ---
// Название: Куртка
// Цена: ¤7,500.00
// Производитель: Nike
// Размер: L
// ---
// 💰 Итого: ¤97,490.00
//
// 🎭 ПОЛИМОРФИЗМ:
// Электроника: iPhone 15
// Цена со скидкой: ¤80,991.00
// Одежда: Куртка
// Цена со скидкой: ¤6,750.00
