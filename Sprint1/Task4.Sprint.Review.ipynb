// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания № 1

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
// ТОВАР
public class Product
{
    private string name;
    private decimal price;
    private int quantity;
    internal string description;

    public Product(string name, decimal price, int quantity, string description)
    {
        this.name = name;
        this.price = price;
        this.quantity = quantity;
        this.description = description;
    }

    public decimal GetTotalPrice()
    {
        return price * quantity;
    }

    public void UpdateQuantity(int amount)
    {
        quantity += amount;
    }

    public string GetProductInfo()
    {
        return $"Товар: {name}\n Цена: {price} руб.\n Количество: {quantity}\n Описание: {description}\n";
    }
}

// ПРОДАВЕЦ
public class Seller
{
    private string name;
    private string employeeId;
    protected decimal salary;
    internal string contactInfo;

    private List<Product> products = new List<Product>();

    public Seller(string name, string employeeId, decimal salary, string contactInfo)
    {
        this.name = name;
        this.employeeId = employeeId;
        this.salary = salary;
        this.contactInfo = contactInfo;
    }

    public void AddProduct(Product product)
    {
        products.Add(product);
    }

    public void SellProduct(Product product, int quantity)
    {
        product.UpdateQuantity(-quantity);
        Console.WriteLine($"{name} продал {quantity} шт. {product.GetProductInfo()}");
    }

    public string GetSellerInfo()
    {
        return $"Продавец: {name}\nID: {employeeId}\n Зарплата: {salary}\n Контакты: {contactInfo}\n";
    }

    public List<Product> GetProducts()
    {
        return products;
    }
}

// МАГАЗИН 
public class Store
{
    private string storeName;
    private string location;
    public string storeHours;

    private List<Seller> sellers = new List<Seller>();

    public Store(string storeName, string location, string storeHours)
    {
        this.storeName = storeName;
        this.location = location;
        this.storeHours = storeHours;
    }

    public void AddSeller(Seller seller)
    {
        sellers.Add(seller);
    }

    public void ListProducts()
    {
        Console.WriteLine($"\n Все товары в магазине {storeName}:");
        foreach (var seller in sellers)
        {
            foreach (var product in seller.GetProducts())
            {
                Console.WriteLine(product.GetProductInfo());
            }
        }
    }

    public string GetStoreInfo()
    {
        return $"Магазин: {storeName}\n Адрес: {location}\n Часы работы: {storeHours}\n";
    }
}


// MAIN 
Product phone = new Product("Смартфон", 15000, 10, "Xiaomi, модель Redmi");
Product tv = new Product("Телевизор", 40000, 5, "LG, 55 дюймов");
Product tshirt = new Product("Футболка", 1500, 20, "Nike, размер L");

Seller seller = new Seller("Иван Иванов", "EMP001", 50000, "ivanov@shop.com");
seller.AddProduct(phone);
seller.AddProduct(tv);
seller.AddProduct(tshirt);

Store store = new Store("Техно-Маркет", "ул. Ленина, 10", "9:00 - 21:00");
store.AddSeller(seller);

Console.WriteLine(store.GetStoreInfo());
Console.WriteLine(seller.GetSellerInfo());

store.ListProducts();

seller.SellProduct(phone, 2);
store.ListProducts();
// Out:
// Магазин: Техно-Маркет
// Адрес: ул. Ленина, 10
// Часы работы: 9:00 - 21:00
//
// Продавец: Иван Иванов
// ID: EMP001
// Зарплата: 50000
// Контакты: ivanov@shop.com
//
//
// Все товары в магазине Техно-Маркет:
// Товар: Смартфон
// Цена: 15000 руб.
// Количество: 10
// Описание: Xiaomi, модель Redmi
//
// Товар: Телевизор
// Цена: 40000 руб.
// Количество: 5
// Описание: LG, 55 дюймов
//
// Товар: Футболка
// Цена: 1500 руб.
// Количество: 20
// Описание: Nike, размер L
//
// Иван Иванов продал 2 шт. Товар: Смартфон
// Цена: 15000 руб.
// Количество: 8
// Описание: Xiaomi, модель Redmi
//
//
// Все товары в магазине Техно-Маркет:
// Товар: Смартфон
// Цена: 15000 руб.
// Количество: 8
// Описание: Xiaomi, модель Redmi
//
// Товар: Телевизор
// Цена: 40000 руб.
// Количество: 5
// Описание: LG, 55 дюймов
//
// Товар: Футболка
// Цена: 1500 руб.
// Количество: 20
// Описание: Nike, размер L
